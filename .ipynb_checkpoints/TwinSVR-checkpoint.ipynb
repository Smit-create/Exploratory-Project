# %% [markdown]
# ## Exploratory Project
#
# ### Smit Lunagariya
#
# #### Implementation of Twin Support Vector Regression

# %%
# Importing required libraries

import math
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
# Importing Twin Support Vector Regression Class from twinsvr
from twinsvr import TwinSVR

# %%
# Creating the artificial data set
x = np.linspace(-10.2,10,num=81).reshape(-1,1)
y = np.sin(x)/x
yhat = y + np.random.normal(scale=0.1,size=81).reshape(-1,1) #Adding noise to original labels

# %%
tsvr = TwinSVR(c1=0.10, c2=0.10, e1=10, e2=10, sigma=81, regul=0.00000001)

# %%
tsvr.fit(x, yhat)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -2.9083e-01 -9.0319e+00  2e+02  1e+01  9e-16
#  1:  5.5785e-02 -8.2311e+00  8e+00  2e-15  3e-15
#  2:  1.9950e-02 -6.3944e-01  7e-01  2e-16  1e-15
#  3: -1.5339e-01 -2.6137e-01  1e-01  1e-16  6e-16
#  4: -2.0652e-01 -2.2567e-01  2e-02  2e-16  4e-16
#  5: -2.1638e-01 -2.1756e-01  1e-03  2e-16  5e-16
#  6: -2.1705e-01 -2.1709e-01  4e-05  2e-16  4e-16
#  7: -2.1707e-01 -2.1707e-01  2e-06  2e-16  5e-16
#  8: -2.1707e-01 -2.1707e-01  1e-07  1e-16  4e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -2.9081e-01 -9.0319e+00  2e+02  1e+01  9e-16
#  1:  5.5788e-02 -8.2311e+00  8e+00  2e-15  2e-15
#  2:  1.9955e-02 -6.3943e-01  7e-01  2e-16  2e-15
#  3: -1.5337e-01 -2.6136e-01  1e-01  1e-16  6e-16
#  4: -2.0651e-01 -2.2565e-01  2e-02  1e-16  5e-16
#  5: -2.1636e-01 -2.1755e-01  1e-03  2e-16  4e-16
#  6: -2.1703e-01 -2.1707e-01  4e-05  2e-16  5e-16
#  7: -2.1705e-01 -2.1705e-01  2e-06  2e-16  5e-16
#  8: -2.1705e-01 -2.1705e-01  1e-07  2e-16  4e-16
# Optimal solution found.
# TwinSVR(c1=0.1, c2=0.1, degree=3, e1=10, e2=10, kernel='gaussian_kernel',
#         regul=1e-08, sigma=81)

# %%
pred = tsvr.predict(x)

# %%
# Visualizing the original synthetic dataset with the output produced
plt.figure(figsize=(12,5))
plt.plot(x, y, label='sinc')
plt.scatter(x, yhat, marker='+', label='sample', color='black')
plt.plot(x, pred, label='twin svr')
plt.ylim([-0.5,1.5])
plt.legend()

# %%
# Evaluation of the results based on various metrics
def Evaluation_of_result(y, ypred):
    def mean_abs_error(y, ypred):
        return mean_absolute_error(y, ypred)

    def root_mean_sq_error(y, ypred):
        return math.sqrt(mean_squared_error(y, ypred))

    def SSE(y, ypred):
        y.reshape(-1,1)
        ypred.reshape(-1,1)
        return mean_squared_error(y, ypred)*(y.shape[0])

    def SST(y):
        y.reshape(-1,1)
        return np.var(y)*(y.shape[0])

    def SSR(ypred):
        ypred.reshape(-1,1)
        return np.var(ypred)*(ypred.shape[0])

    print("MAE: ", mean_abs_error(y, ypred))
    print("RMSE: ", root_mean_sq_error(y, ypred))
    print("SSE: ", SSE(y, ypred))
    print("SSR: ", SSR(ypred))
    print("SST: ", SST(y))
    print("SSR/SST: ", SSR(ypred)/SST(y))
    print("SSE/SST: ", SSE(y,ypred)/SST(y))

# %%
print("The evaluation of results of Twin SVR are as follows:")
Evaluation_of_result(y,pred)
# Out:
# The evaluation of results of Twin SVR are as follows:
# MAE:  0.04022058567481486
# RMSE:  0.04639021018424741
# SSE:  0.1743161796760308
# SSR:  10.288383036416626
# SST:  9.942618950174554
# SSR/SST:  1.0347759567147046
# SSE/SST:  0.017532219684731103
